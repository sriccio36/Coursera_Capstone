# %%
# The code was removed by Watson Studio for sharing.
# Out:
# (103, 3)

# %%
body = client_045f7a7a9ce54f049136c01efcd0e9c2.get_object(Bucket='course9datasciencecapstoneproject-donotdelete-pr-nybrds73a41gom',Key='Geospatial_Coordinates.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

geo_df = pd.read_csv(body)
merged_df = pd.merge(left=df, right=geo_df, left_on='Postalcode', right_on='Postal Code')
longlat_df = merged_df.drop(columns=['Postal Code'])
longlat_df.head()
# Out:
#   Postalcode           Borough                                  Neighborhood  \
# 0        M3A        North York                                     Parkwoods
# 1        M4A        North York                              Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park , Harbourfront
# 3        M6A        North York             Lawrence Manor , Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park , Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %%
# !pip install folium
import pandas as pd
import folium
# Out:
# ...
#      |████████████████████████████████| 102kB 7.2MB/s ta 0:00:011
# ...

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
neighborhoods_data = longlat_df['features']
neighborhoods_data[0]

neighborhood =
# Out:
#   File "<ipython-input-5-074e5d4a18f2>", line 4
#     neighborhood =
#                   ^
# SyntaxError: invalid syntax

# %%
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="tor_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
CLIENT_ID = 'WLE1TSIOKC4KO0SJ035ET1ABEINSS3BQWXXXPEA5TNCIPQG1' # your Foursquare ID
CLIENT_SECRET = 'WU4X3QAVIO20TLTYFXOJV3KNHRYEKLZ3GCIT1JNO3OYNI20S' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT =30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: WLE1TSIOKC4KO0SJ035ET1ABEINSS3BQWXXXPEA5TNCIPQG1
# CLIENT_SECRET:WU4X3QAVIO20TLTYFXOJV3KNHRYEKLZ3GCIT1JNO3OYNI20S

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(longlat_df['Latitude'], longlat_df['Longitude'], longlat_df['Borough'], longlat_df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Search for a specific venue catagory, in this case, Pizza #
search_query = 'italian'
radius = 500
print(search_query + ' .... OK!')
# Out:
# italian .... OK!

# %%
# Deine the corresponding URL #
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=WLE1TSIOKC4KO0SJ035ET1ABEINSS3BQWXXXPEA5TNCIPQG1&client_secret=WU4X3QAVIO20TLTYFXOJV3KNHRYEKLZ3GCIT1JNO3OYNI20S&ll=43.6534817,-79.3839347&v=20180605&query=italian&radius=500&limit=30'

# %%
# Send the GET request and examine the results #
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5eb80d0bc94979001bff7872'},
#  'response': {'venues': [{'id': '4c787c9181bca0936180fa14',
#     'name': 'Classic italian style pizza food truck',
#     'location': {'address': 'CNE Midway',
#      'lat': 43.652144,
#      'lng': -79.381118,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652144,
#        'lng': -79.381118}],
#      'distance': 271,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['CNE Midway', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1589120296',
#     'hasPerk': False},
#    {'id': '573df789498e03dd8e54b166',
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1cb941735', 'name': 'F...    False
# 1  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 2  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 3  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
# 4  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...    False
#
#                          id location.address location.cc location.city  \
# 0  4c787c9181bca0936180fa14       CNE Midway          CA       Toronto
# 1  573df789498e03dd8e54b166       595 Bay St          CA       Toronto
# 2  51bf3866498e55ee55df8db0              NaN          CA       Toronto
# 3  4f88cf84e4b002b90ab3b9b9              NaN          CA           NaN
# 4  5e594c8a3de308000870c948    15 Elm Street          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada                  NaN                271
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                      name          categories  \
# 0  Classic italian style pizza food truck          Food Truck
# 1                Mustachio Italian Eatery  Italian Restaurant
# 2                       The Fresh Italian  Italian Restaurant
# 3                      LA's Italian + Bar  Italian Restaurant
# 4                 Elm Street Italian Deli  Italian Restaurant
# 5                The Fresh Italian Eatery  Italian Restaurant
# 6                                  Sbarro         Pizza Place
# 7                        Little Anthony's  Italian Restaurant
#
#                        address  cc     city country              crossStreet  \
# 0                   CNE Midway  CA  Toronto  Canada                      NaN
# 1                   595 Bay St  CA  Toronto  Canada                Dundas St
# 2                          NaN  CA  Toronto  Canada                      NaN
# 3                          NaN  CA      NaN  Canada                      NaN
# ...

# %%
# Visualize the Italian restaurants that are nearby #
dataframe_filtered.name
# Out:
# 0    Classic italian style pizza food truck
# 1                  Mustachio Italian Eatery
# 2                         The Fresh Italian
# 3                        LA's Italian + Bar
# 4                   Elm Street Italian Deli
# 5                  The Fresh Italian Eatery
# 6                                    Sbarro
# 7                          Little Anthony's
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='red',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Lets get the ratings of each Italian Restaurant #
venue_id = '4c787c9181bca0936180fa14' # ID of Classic italian style pizza food truck
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4c787c9181bca0936180fa14?client_id=WLE1TSIOKC4KO0SJ035ET1ABEINSS3BQWXXXPEA5TNCIPQG1&client_secret=WU4X3QAVIO20TLTYFXOJV3KNHRYEKLZ3GCIT1JNO3OYNI20S&v=20180605'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'price', 'likes', 'dislike', 'ok', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'seasonalHours', 'pageUpdates', 'inbox', 'attributes'])
# {'id': '4c787c9181bca0936180fa14',
#  'name': 'Classic italian style pizza food truck',
#  'contact': {},
#  'location': {'address': 'CNE Midway',
#   'lat': 43.652144,
#   'lng': -79.381118,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 43.652144,
#     'lng': -79.381118}],
#   'cc': 'CA',
#   'city': 'Toronto',
#   'state': 'ON',
#   'country': 'Canada',
#   'formattedAddress': ['CNE Midway', 'Toronto ON', 'Canada']},
#  'canonicalUrl': 'https://foursquare.com/v/classic-italian-style-pizza-food-truck/4c787c9181bca0936180fa14',
#  'categories': [{'id': '4bf58dd8d48988d1cb941735',
#    'name': 'Food Truck',
#    'pluralName': 'Food Trucks',
# ...

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venue_id = '573df789498e03dd8e54b166' # ID of Mustachio Italian Eatery
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venue_id = '51bf3866498e55ee55df8db0' # ID of The Fresh Italian	
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venue_id = '4f88cf84e4b002b90ab3b9b9' # ID of LA's Italian + Bar
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venue_id = '5e594c8a3de308000870c948' # ID of Elm Street Italian Deli
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venue_id = '526fe29411d2aeb3803013b0' # ID of The Fresh Italian Eatery
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venue_id = '4b4a2d09f964a520687d26e3' # ID of Sbarros
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 4.6

# %%
venue_id = '4b846dd4f964a520dc3431e3' # ID of Little Anthonys
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.7

# %%
# How many Italian Restaurants in Toronto #
dataframe_filtered.shape
# Out:
# (8, 15)

# %%
# Population of 100k Toronto Residents per Italian Restaurant #
Tor_pop = 2,930,000
tor_pop_per_100k = 2,930,000 / 100000
tor_pop_per_100k
Tor_italian_restaurants = 8
Tor_pop_per_Italian_Restaurant = 2930/8
Tor_pop_per_Italian_Restaurant
# Out:
# 366.25

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(longlat_df['Latitude'], longlat_df['Longitude'], longlat_df['Borough'], longlat_df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
    
# add the Italian restaurants as red circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='red',
        popup=label,
        fill = True,
        fill_color='red',
        fill_opacity=0.6
    ).add_to(map_toronto)

# display map
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
